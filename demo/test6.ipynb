# %%
### 可视化

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

current_directory = os.path.dirname(os.path.abspath('__file__'))
sys.path.append(current_directory)

from base import testBase as tb

ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

tb.myprint("原数据")
print(ts)

tb.myprint("累计计算后的数据")
ts = ts.cumsum()
print(ts)

tb.myprint("可视化")
ts.plot()


df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
tb.myprint("原数据")
print(df)

df = df.cumsum()
tb.myprint("绘制所有带标签的列")
plt.figure()
df.plot()
plt.legend(loc='best')
# Out:
#
# ============== 原数据 ==============
#
# 2000-01-01    0.754473
# 2000-01-02    0.013067
# 2000-01-03    0.198969
# 2000-01-04    0.593234
# 2000-01-05   -0.293770
#                 ...
# 2002-09-22    0.130238
# 2002-09-23   -0.257898
# 2002-09-24   -0.624476
# 2002-09-25   -0.135355
# 2002-09-26   -1.593814
# Freq: D, Length: 1000, dtype: float64
#
# ============== 累计计算后的数据 ==============
#
# 2000-01-01    0.754473
# 2000-01-02    0.767540
# 2000-01-03    0.966509
# 2000-01-04    1.559743
# 2000-01-05    1.265973
#                 ...
# 2002-09-22   -6.492211
# 2002-09-23   -6.750110
# 2002-09-24   -7.374586
# 2002-09-25   -7.509941
# 2002-09-26   -9.103755
# Freq: D, Length: 1000, dtype: float64
#
# ============== 可视化 ==============
#
#
# ============== 原数据 ==============
#
#                    A         B         C         D
# 2000-01-01 -0.372841  0.548315 -1.852704 -0.081426
# 2000-01-02  0.526484  0.618936  0.214984  0.950948
# 2000-01-03  0.478476 -0.180831  1.077154 -0.036432
# 2000-01-04 -2.290088 -0.481664  0.348008  0.857015
# 2000-01-05  0.023785 -0.964848 -0.566501  0.106916
# ...              ...       ...       ...       ...
# 2002-09-22  1.105455  0.167569 -0.383276 -0.676408
# 2002-09-23  1.113615  0.393214 -1.030122 -1.105388
# 2002-09-24 -0.082845 -0.234366 -2.118369 -0.243607
# 2002-09-25 -1.701231  0.528559  1.639875  0.590061
# 2002-09-26 -0.139061 -1.661130  0.651433  0.024211
#
# [1000 rows x 4 columns]
#
# ============== 绘制所有带标签的列 ==============
